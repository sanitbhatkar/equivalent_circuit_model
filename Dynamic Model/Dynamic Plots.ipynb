# %%
os.chdir("G:\Sanit_Horizontal\Batteries\Battery codes\Equivalent circuit model\dyn_data")

# %%
script_list = ['s1','s2','s3']
str = '50_P25'

# %%
for i in range(len(script_list)):
    
    file_name = f'A123_DYN_{str}_{script_list[i]}.csv'
    
    df  = pd.read_csv(file_name)
    print(df.columns)
    
    fig,ax1 = plt.subplots()
    
    ax1.plot(df['time'],df[' current'])
    ax1.set_xlabel('Test Time (s)', size = 14)
    ax1.set_ylabel('Current (A)', size = 14 , color = 'C0')
    
    
    ax2 = ax1.twinx()

    ax2.plot(df['time'],df[' voltage'], color = 'red')
    ax2.set_ylabel('Voltage (V)', size = 14 , color = 'red')
    
    plt.show()
# Out:
# Index(['time', ' step', ' current', ' voltage', ' chgAh', ' disAh'], dtype='object')
# Index(['time', ' step', ' current', ' voltage', ' chgAh', ' disAh'], dtype='object')
# Index(['time', ' step', ' current', ' voltage', ' chgAh', ' disAh'], dtype='object')
